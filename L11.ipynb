# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_datareader.data import get_data_yahoo

# %%
tickers = ["IVV","IDEV","IUSB","IEMG","IAGG","IJH","IJR"]
get_data_yahoo(tickers, '01/01/2015', '12/31/2019')
# Out:
# Attributes   Adj Close                                              \
# Symbols            IVV       IDEV       IUSB       IEMG       IAGG
# Date
# 2014-12-31  183.877716        NaN  43.015728  40.448051        NaN
# 2015-01-02  183.753281        NaN  43.173847  40.069641        NaN
# 2015-01-05  180.526749        NaN  43.220840  39.459007        NaN
# 2015-01-06  178.900208        NaN  43.272114  39.252586        NaN
# 2015-01-07  181.113419        NaN  42.887550  40.061043        NaN
# ...                ...        ...        ...        ...        ...
# 2019-12-24  316.480499  56.514118  50.483654  52.225918  53.868710
# 2019-12-26  318.118591  56.915134  50.522446  52.637142  53.829487
# 2019-12-27  318.059723  56.983601  50.600044  52.862343  53.878517
# 2019-12-30  316.343201  56.699955  50.609741  52.490276  53.760860
# 2019-12-31  317.059235  56.895569  50.541851  52.637142  53.721634
#
# Attributes                              Close                        ...  \
# ...

# %%
def plusfuction(arg1):
    plus = arg1 + 100
    return plus

# %%
def get_AdPrices(str):
    data = get_data_yahoo(str, '01/01/2010', '12/31/2019', interval='m')
    adj_price= data['Adj Close']
    return adj_price

# %%
get_AdPrices("IVV")
# Out:
# Date
# 2010-01-01     86.586945
# 2010-02-01     89.313385
# 2010-03-01     94.372208
# 2010-04-01     96.306892
# 2010-05-01     88.601677
#                  ...
# 2019-08-01    285.387390
# 2019-09-01    289.509125
# 2019-10-01    297.226990
# 2019-11-01    308.035461
# 2019-12-01    315.033142
# Name: Adj Close, Length: 120, dtype: float64
